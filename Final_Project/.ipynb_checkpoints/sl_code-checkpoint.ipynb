# %% [markdown]
# # Import data

# %% [markdown]
# Parser for the .tcx files

# %%
# !pip install python-tcxparser
# Out:
# Collecting python-tcxparser
#   Downloading python_tcxparser-2.0.0-py2.py3-none-any.whl (6.3 kB)
# Requirement already satisfied: lxml in c:\users\juanm\anaconda3\envs\data_science_general\lib\site-packages (from python-tcxparser) (4.6.1)
# Installing collected packages: python-tcxparser
# Successfully installed python-tcxparser-2.0.0

# %%
import csv
import json
import pandas as pd
import numpy as np
import tcxparser
import os
import glob
import time

# %%
paths_to_data = {'fit':'./Data/Fit', 'arduino':'./data/arduino/Run'}

# %% [markdown]
# ## Google Fit

# %% [markdown]
# ### Parse .tcx files

# %%
path_to_tcx = 'Activities/*_Corsa.tcx'

file_names = sorted(glob.iglob(os.path.join(paths_to_data['fit'], path_to_tcx)))

# %%
file_names
# Out:
# ['./data/fit/Activities/2021-03-31T22_13_48+02_00_PT42.822S_Corsa.tcx',
#  './data/fit/Activities/2021-04-13T19_19_58+02_00_PT34M22.717S_Corsa.tcx',
#  './data/fit/Activities/2021-04-16T19_21_25+02_00_PT33M4.030S_Corsa.tcx',
#  './data/fit/Activities/2021-04-17T19_12_36+02_00_PT33M52.367S_Corsa.tcx',
#  './data/fit/Activities/2021-04-20T19_10_11+02_00_PT33M12.221S_Corsa.tcx',
#  './data/fit/Activities/2021-04-22T19_15_54+02_00_PT32M56.470S_Corsa.tcx',
#  './data/fit/Activities/2021-04-25T18_34_08+02_00_PT25M35.484S_Corsa.tcx',
#  './data/fit/Activities/2021-04-27T18_39_03+02_00_PT32M43.650S_Corsa.tcx',
#  './data/fit/Activities/2021-04-30T18_53_48+02_00_PT32M23.505S_Corsa.tcx',
#  './data/fit/Activities/2021-05-02T19_18_25+02_00_PT33M37.812S_Corsa.tcx',
#  './data/fit/Activities/2021-05-06T18_48_14+02_00_PT33M57.126S_Corsa.tcx',
#  './data/fit/Activities/2021-05-07T18_55_09+02_00_PT33M7.771S_Corsa.tcx']

# %%
example_file = file_names[1]
tcx = tcxparser.TCXParser(example_file)

# %%
dir(tcx)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'activity',
#  'activity_notes',
#  'activity_type',
#  'altitude_avg',
#  'altitude_max',
#  'altitude_min',
#  'altitude_points',
#  'ascent',
#  'cadence_avg',
#  'cadence_max',
#  'cadence_values',
#  'calories',
#  'completed_at',
#  'descent',
#  'distance',
#  'distance_units',
#  'distance_values',
#  'duration',
#  'hr_avg',
#  'hr_max',
#  'hr_min',
#  'hr_percent_in_zones',
#  'hr_values',
#  'latitude',
#  'longitude',
#  'pace',
#  'position_values',
#  'root',
#  'started_at',
#  'time_values']

# %%
example_file
# Out:
# './data/fit/Activities/2021-04-13T19_19_58+02_00_PT34M22.717S_Corsa.tcx'

# %%
tcx.position_values()
# Out:
# [(41.94089126586914, 12.52275276184082),
#  (41.94089889526367, 12.52273941040039),
#  (41.94090270996094, 12.522727012634277),
#  (41.94091033935547, 12.522714614868164),
#  (41.94092559814453, 12.522695541381836),
#  (41.94093704223633, 12.522684097290039),
# %%
min_int = np.amin(sampling_intervals)
max_int = np.amax(sampling_intervals)

print('Min:\t', min_int, '\nMax:', max_int)
# Out:
# Min:	 119 milliseconds
# Max: 10717 milliseconds

# %% [markdown]
# The tcx file contains only the data regarding the altitude, the space coordinates (latitude and longitude), the distance and the timestamp. These values are sampled at a variable frequency.

# %%
min(tcx.altitude_points())
# Out:
# 48.339359283447266

# %%
max(tcx.altitude_points())
# Out:
# 75.64495849609375

# %%
def load_tcx(file_list):
    """
    Load tcx files into pandas DataFrame
    
    Known issue: 
    the lists altitude, timestamp and distance have not the same length;
    we don't know the position of the missing data (potential values' shift);
    """
    df = pd.DataFrame(columns=['session','timestamp','altitude','distance'])
    
    for i in range(0, len(file_list)):
        tcx_obj = tcxparser.TCXParser(file_list[i])
        data_dict = {'session':[i+1]*len(tcx_obj.time_values()), 
                     'timestamp':tcx_obj.time_values(), 
                     'altitude':tcx_obj.altitude_points(), 
                     'distance':tcx_obj.distance_values()}
        tmp_df = pd.DataFrame(data_dict)
        df = pd.concat([df, tmp_df])
        
    return df.sort_values(by='timestamp')

# %%
tcx_df = load_tcx(file_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-9a315d7869ce> in <module>
# ----> 1 tcx_df = load_tcx(file_names)
#
# <ipython-input-113-16aea89fc862> in load_tcx(file_list)
#       8                      'altitude':tcx_obj.altitude_points(),
#       9                      'distance':tcx_obj.distance_values()}
# ---> 10         tmp_df = pd.DataFrame(data_dict)
#      11         df = pd.concat([df, tmp_df])
#      12
#
# ~/Documents/University/Master/SL/.venv/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~/Documents/University/Master/SL/.venv/lib/python3.9/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~/Documents/University/Master/SL/.venv/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# ~/Documents/University/Master/SL/.venv/lib/python3.9/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     399             lengths = list(set(raw_lengths))
#     400             if len(lengths) > 1:
# --> 401                 raise ValueError("arrays must all be same length")
#     402
#     403             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# ### Parse JSON

# %% [markdown]
# #### All Sessions

# %% [markdown]
# The data inside the folder **All Sessions** contains just summaries regarding the activity:
#
# - startTime
# - endTime
# - duration (endTime - startTime)
# - final step count
# - distance
# - average speed
# - time of activity (in minutes)
# - estimated calories

# %%
path_to_raw_json = 'All Sessions/*RUNNING*'

file_names = glob.iglob(os.path.join(paths_to_data['fit'], path_to_raw_json))

# %%
ex_file = file_names.__next__()


with open(ex_file, 'r') as json_file:
    json_content = json.load(json_file)

# %%
json_content
# Out:
# {'fitnessActivity': 'running',
#  'startTime': '2021-05-02T17:18:25.616Z',
#  'endTime': '2021-05-02T17:52:04.339Z',
#  'duration': '2017.812s',
#  'segment': [{'fitnessActivity': 'running',
#    'startTime': '2021-05-02T17:18:25.616Z',
#    'endTime': '2021-05-02T17:52:03.428Z'}],
#  'aggregate': [{'metricName': 'com.google.heart_minutes.summary',
#    'floatValue': 66.0},
#   {'metricName': 'com.google.calories.expended',
#    'floatValue': 451.66382590308785},
#   {'metricName': 'com.google.step_count.delta', 'intValue': 5131},
#   {'metricName': 'com.google.distance.delta', 'floatValue': 6139.019788086414},
#   {'metricName': 'com.google.speed.summary', 'floatValue': 3.047296038689514},
#   {'metricName': 'com.google.active_minutes', 'intValue': 34}]}

# %% [markdown]
# #### All Data

# %%
path_to_derived_json = 'All Data/*step_count.delta*'

file_names = glob.iglob(os.path.join(paths_to_data['fit'], path_to_derived_json))

# %%
ex_file = file_names.__next__()


with open(ex_file, 'r') as json_file:
    json_content = json.load(json_file)

# %%
ex_file
# Out:
# './data/fit/All Data/derived_com.google.step_count.delta_com.google(5).json'

# %%
json_content
# Out:
# {'Data Source': 'derived:com.google.step_count.delta:com.google.android.gms:motorola:moto x4:608951edf41c2b1d:derive_step_deltas<-raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#  'Data Points': [{'fitValue': [{'value': {'intVal': 78}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617221667754424311,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617221551018894293,
#    'modifiedTimeMillis': 1617222356498,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 10}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617223855802523901,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617223795802523901,
#    'modifiedTimeMillis': 1617225088590,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 14}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617227093235271914,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617227033235271914,
#    'modifiedTimeMillis': 1617257623673,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 16}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617227241442428775,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617227181442428775,
#    'modifiedTimeMillis': 1617257623673,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 43}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617259907899598423,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617259821899597399,
#    'modifiedTimeMillis': 1617261189157,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 11}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617263553513134686,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617263493513134686,
#    'modifiedTimeMillis': 1617264947068,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 39}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617272344224597354,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617272266224600426,
#    'modifiedTimeMillis': 1617275955679,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 24}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617272475142681452,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617272415142681452,
#    'modifiedTimeMillis': 1617275955679,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 30}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617277235846855360,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617277175846853312,
#    'modifiedTimeMillis': 1617280026529,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 25}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617283566452607709,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617283506452607709,
#    'modifiedTimeMillis': 1617283621962,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 15}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617295134614067319,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617295074614067319,
#    'modifiedTimeMillis': 1617298325458,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 29}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617295447213492366,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617295387213492366,
#    'modifiedTimeMillis': 1617298325458,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 12}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617298427035309343,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617298367035309343,
#    'modifiedTimeMillis': 1617305298786,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 44}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617298512401990066,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617298427035309343,
#    'modifiedTimeMillis': 1617305298786,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 47}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617298642511491801,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617298548511486681,
#    'modifiedTimeMillis': 1617305298786,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 17}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617298843243043510,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617298783243043510,
#    'modifiedTimeMillis': 1617305298786,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 15}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617298944066115826,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617298884066115826,
#    'modifiedTimeMillis': 1617305298786,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 25}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617299195180861135,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617299135180861135,
#    'modifiedTimeMillis': 1617305298786,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 14}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617299253007930338,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617299195180861135,
#    'modifiedTimeMillis': 1617305298786,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 29}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617299623005664184,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617299563005664184,
#    'modifiedTimeMillis': 1617305298786,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 15}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617299679803749779,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617299623005664184,
#    'modifiedTimeMillis': 1617305298786,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 106}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1617299748688000000,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1617299679803749779,
#    'modifiedTimeMillis': 1617305298786,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal':

#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 42}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1618512862706418386,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1618512778706420434,
#    'modifiedTimeMillis': 1618512929704,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 15}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1618513099304622833,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1618513039304622833,
#    'modifiedTimeMillis': 1618517138523,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 10}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:motorola:moto x4:608951edf41c2b1d:Step Counter',
#    'endTimeNanos': 1618513373172004358,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1618513313172004358,
#    'modifiedTimeMillis': 1618517138523,
#    'rawTimestampNanos': 0},
#   ...]}

# %%
def extract_steps(file_iter):
    
    for file_name in file_iter:
        
        with open(file_name, 'r') as json_file:
            json_content = json.load(json_file)
            
            data_list = json_content['Data Points']
            data_dict = {}
            
            for index in range(len(data_list)):
                start = data_list[index]['startTimeNanos'] // 1000000000
                end =  data_list[index]['endTimeNanos'] // 1000000000
                data_dict[index] = [start,end, data_list[index]['fitValue'][0]['value']['intVal']]
                
    data_frame = pd.DataFrame.from_dict(data_dict, columns=['start','end','steps'], orient='index')
    
    data_frame['start'] = data_frame['start'].dt.tz_localize('Europe/Rome')
    data_fame['end'] = data_fame['end'].dt.tz_localize('Europe/Rome')
    data_frame['interval'] = data_frame.end - data_frame.start
    data_frame['session'] = None
    data_frame.sort_values(by='start')
    return data_frame

# %% [markdown]
# ---

# %% [markdown]
# ## Arduino

# %% [markdown]
# List all the files in the folder

# %%
file_names = glob.glob(os.path.join(paths_to_data['arduino'], '*'))
file_names
# Out:
# ['./data/arduino/Run/Run_9.csv',
#  './data/arduino/Run/Run_3.csv',
#  './data/arduino/Run/Run_8.csv',
#  './data/arduino/Run/Run_4.csv',
#  './data/arduino/Run/Run_5.csv',
#  './data/arduino/Run/Run_2.csv',
#  './data/arduino/Run/Run_1.csv',
#  './data/arduino/Run/Run_10.csv',
#  './data/arduino/Run/Run_6.csv',
#  './data/arduino/Run/Run_7.csv']

# %% [markdown]
# Load the files and store the content in a DataFrame

# %%
def load_arduino(file_list):
    
    df = pd.DataFrame(columns=['session', 'timestamp','DecibelSource','LinearAccelerometerSensor','AccX','AccY','AccZ'])
    
    for file_name in file_list:
        tmp_df = pd.read_csv(file_name)
        tmp_df['session'] = int(file_name.split('/')[-1][4:-4])
        df = pd.concat([df, tmp_df])
        
    return df.sort_values(by='timestamp')

# %%
df = load_arduino(file_names)

# %%
df.head(30)
# Out:
#    session      timestamp  DecibelSource  LinearAccelerometerSensor      AccX  \
# 0        1  1618334405372       6.412549                        NaN       NaN
# 1        1  1618334405394            NaN                        NaN -1.666458
# 2        1  1618334405413       7.082729                        NaN       NaN
# 3        1  1618334405442            NaN                        NaN       NaN
# 4        1  1618334405453       4.674826                        NaN       NaN
# 5        1  1618334405463            NaN                   1.277912  0.027664
# 6        1  1618334405472            NaN                        NaN -0.711716
# 7        1  1618334405490            NaN                        NaN -0.587296
# 8        1  1618334405493      10.108893                        NaN       NaN
# 9        1  1618334405494            NaN                        NaN -0.300156
# 10       1  1618334405495            NaN                        NaN       NaN
# 11       1  1618334405514            NaN                        NaN -0.233154
# 12       1  1618334405529            NaN                   1.050633 -0.364761
# 13       1  1618334405531            NaN                        NaN -0.541824
# 14       1  1618334405533      16.853068                        NaN       NaN
# 15       1  1618334405546            NaN                        NaN -0.955780
# 16       1  1618334405559            NaN                        NaN -1.166351
# 17       1  1618334405560            NaN                        NaN -0.726074
# 18       1  1618334405573      37.192507                        NaN -0.498764
# 19       1  1618334405580            NaN                   1.957239 -0.292969
# 20       1  1618334405590            NaN                        NaN -0.240326
# 21       1  1618334405603            NaN                        NaN -0.319290
# 22       1  1618334405613      15.856810                        NaN       NaN
# 23       1  1618334405621            NaN                        NaN       NaN
# 24       1  1618334405622            NaN                        NaN -0.431763
# 25       1  1618334405630            NaN                        NaN       NaN
# 26       1  1618334405631            NaN                        NaN -0.685394
# 27       1  1618334405642            NaN                   2.899095 -0.876816
# 28       1  1618334405649            NaN                        NaN -1.479813
# 29       1  1618334405653      38.837689                        NaN       NaN
#
#         AccY       AccZ
# 0        NaN        NaN
# 1   3.380386   7.740662
# 2        NaN        NaN
# 3        NaN  11.349045
# 4        NaN        NaN
# 5   4.143707  10.260315
# 6   4.227448   9.391724
# 7   4.112595   9.934891
# 8        NaN        NaN
# 9        NaN   9.918137
# 10  4.055161        NaN
# 11  4.098236   9.686035
# 12  4.122162   9.183548
# 13  4.150879   9.130905
# 14       NaN        NaN
# 15  3.937912   9.870285
# 16  3.531143  10.825012
# 17  2.782181  11.394516
# 18  1.832230  11.490219
# 19  1.238815  11.514145
# 20  1.145493  11.796509
# 21  1.480484  12.040573
# 22       NaN        NaN
# 23       NaN  12.045349
# 24  1.851379  11.516541
# 25       NaN  10.619232
# 26  2.334732        NaN
# 27  2.368225   9.970779
# 28  2.459152   9.322327
# 29       NaN        NaN

# %% [markdown]
# Fix the NaN values:

# %%
def fill_nan(df, method):
    """
    Fill NaN values
    """
    
    df['DecibelSource'] = df['DecibelSource'].interpolate(method=method)
    df['LinearAccelerometerSensor'] = df['LinearAccelerometerSensor'].interpolate(method=method)
    df['AccX'] = df['AccX'].interpolate(method=method)
    df['AccY'] = df['AccY'].interpolate(method=method)
    df['AccZ'] = df['AccZ'].interpolate(method=method)
    
    return df

# %%
df = fill_nan(df, method='linear')

# %%
df['DecibelSource'][0:5000:1].plot(figsize=(16,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Check the records

# %%
def fix_nans(df):
    
    sessions = list(df['session'].unique())
    columns = df.columns.drop(['session', 'timestamp'])
    
    for session in sessions:
        for column in columns:
            not_null_mask = df[column].notnull()
            x0 = df[not_null_mask]['timestamp']
            x1 = x0.shift(-1)
            y0 = df[not_null_mask]['timestamp']
            y1 = y0.shift(-1)
            for i,j in zip(x0.index, x0.iloc[1:].index):
                if i < j:
                    m = (y1[i] - y0[i]) / (x1[i] - x0[i])
                    intercept = y0[i] - m * x0[i]
                    line = lambda x,m,c: m*x + c
                    df[(i+1):j][column] = df[(i+1):j]['timestamp'].apply(line, args=(m,intercept))
    return something

# %%
test_df = pd.DataFrame({'a':[1,2,3,None,5,6], 'b':[1,2,3,4,5,6]})

# %%
z = test_df['a'].shift(-1)

# %%
z
# Out:
# 0    2.0
# 1    3.0
# 2    NaN
# 3    5.0
# 4    6.0
# 5    NaN
# Name: a, dtype: float64

# %%
test_df['a'] - z
# Out:
# 0   -1.0
# 1   -1.0
# 2   -1.0
# 3   -1.0
# 4   -1.0
# 5    NaN
# Name: a, dtype: float64

# %%
test_df[test_df['a'].notnull()]['a'].shift(-1)[4]
# Out:
# 6.0

# %%
test_df[test_df['a'].notnull()]['a'][1:4]
# Out:
# 1    2.0
# 2    3.0
# 4    5.0
# Name: a, dtype: float64

# %%
df[0:3]
# Out:
#   session      timestamp  DecibelSource  LinearAccelerometerSensor      AccX  \
# 0       1  1618334405372       6.412549                        NaN       NaN
# 1       1  1618334405394            NaN                        NaN -1.666458
# 2       1  1618334405413       7.082729                        NaN       NaN
#
#        AccY      AccZ
# 0       NaN       NaN
# 1  3.380386  7.740662
# 2       NaN       NaN

# %%
session_time = []

for i in range(1, 11):
    session_time.append((df[df['session'] == i].iloc[-1]['timestamp']  - df[df['session'] == i].iloc[0]['timestamp']) / 60000)

# %%
session_time
# Out:
# [34.135983333333336,
#  32.7286,
#  33.73211666666667,
#  33.07163333333333,
#  32.6069,
#  25.378233333333334,
#  32.527566666666665,
#  32.18376666666666,
#  33.44681666666666,
#  33.76665]

# %%
df.tail(50)
# Out:
#        session      timestamp  DecibelSource  LinearAccelerometerSensor  \
# 321826      10  1620321727436      12.192029                   1.974043
# 321827      10  1620321727448      11.009868                   1.890198
# 321828      10  1620321727463       9.827708                   1.806352
# 321829      10  1620321727473      11.129404                   1.722507
# 321830      10  1620321727499      12.431099                   2.121587
# 321831      10  1620321727503      13.732795                   2.520668
# 321832      10  1620321727516      13.722434                   2.919749
# 321833      10  1620321727528      13.712073                   3.318829
# 321834      10  1620321727541      13.701712                   3.165228
# 321835      10  1620321727544      13.691351                   3.011626
# 321836      10  1620321727556      17.380820                   2.858024
# 321837      10  1620321727557      21.070290                   2.704422
# 321838      10  1620321727569      24.759760                   2.550820
# 321839      10  1620321727574      28.449230                   2.397218
# 321840      10  1620321727584      32.138700                   2.243617
# 321841      10  1620321727585      29.834385                   2.090015
# 321842      10  1620321727602      27.530070                   2.137988
# 321843      10  1620321727606      25.225756                   2.185960
# 321844      10  1620321727607      22.921441                   2.233933
# 321845      10  1620321727614      20.617126                   2.281906
# 321846      10  1620321727624      18.312812                   2.329879
# 321847      10  1620321727626      17.071598                   2.377851
# 321848      10  1620321727635      15.830385                   2.425824
# 321849      10  1620321727636      14.589171                   2.473797
# 321850      10  1620321727644      13.347958                   2.521770
# 321851      10  1620321727657      12.106744                   2.397679
# 321852      10  1620321727663      10.865531                   2.273589
# 321853      10  1620321727664       9.624317                   2.149498
# 321854      10  1620321727675       9.962008                   2.025408
# 321855      10  1620321727683      10.299699                   1.901317
# 321856      10  1620321727693      10.637389                   1.777226
